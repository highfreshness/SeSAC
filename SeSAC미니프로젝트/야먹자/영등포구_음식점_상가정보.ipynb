# %%
import pandas as pd

# %%
df = pd.read_csv('소상공인_220630/소상공인시장진흥공단_상가(상권)정보_서울_202206.csv', encoding='utf-8')
df.head(2)
# Out:
#      상가업소번호    상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명 상권업종소분류코드  \
# 0  23324279  제중건강원  NaN         D       소매       D10    건강/미용식품    D10A07
# 1  24525909  민속악기사  NaN         D       소매       D04  취미/오락관련소매    D04A09
#
#   상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0      건강원   G47216  ...  1156010600100410002034626  NaN
# 1     악기판매   G47593  ...  1120012200101420011000227  NaN
#
#                      도로명주소   구우편번호   신우편번호  동정보  층정보  호정보          경도  \
# 0  서울특별시 영등포구 영중로14길 11-17  150035  7250.0  NaN    1  NaN  126.907168
# 1         서울특별시 성동구 용답5길 2  133849  4803.0  NaN  NaN  NaN  127.049018
#
#           위도
# 0  37.520613
# 1  37.566857
#
# [2 rows x 39 columns]

# %%
df['구'] = df['도로명주소'].apply(lambda x : x.split()[1])

# %%
df['구'].value_counts()
# Out:
# 강남구     33454
# 송파구     21050
# 서초구     20069
# 강서구     17182
# 마포구     16740
# 중구      16599
# 영등포구    14987
# 종로구     14258
# 강동구     14004
# 광진구     13529
# 구로구     13008
# 관악구     12606
# 동대문구    12550
# 은평구     12094
# 양천구     11960
# 노원구     11903
# 성북구     11872
# 중랑구     11107
# 용산구     11022
# 성동구     10672
# 금천구      9715
# 동작구      9573
# 서대문구     9444
# 강북구      8877
# 도봉구      7954
# Name: 구, dtype: int64

# %%
new_df = df[(df['구']=='영등포구') & (df['상권업종대분류명']=='음식')]

# %%
new_df.to_csv('영등포구_음식점_상가정보.csv', encoding='utf-8-sig')

# %%
df[df['상권업종대분류명']=='음식']
# Out:
#           상가업소번호        상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 4       17174175        비지트    NaN         Q       음식       Q01       한식
# 5       17174119       쓰리에프    NaN         Q       음식       Q01       한식
# 6       17174040         다향    NaN         Q       음식       Q01       한식
# 7       25530299     고향생막걸리    NaN         Q       음식       Q09     유흥주점
# 12      17163092  도전최강달인왕만두    NaN         Q       음식       Q01       한식
# ...          ...        ...    ...       ...      ...       ...      ...
# 346210  18450530    샐럽스프진관점    NaN         Q       음식       Q04       분식
# 346217  18445536       도너츠윤  덕성여대점         Q       음식       Q12   커피점/카페
# 346221  18453167          텐    NaN         Q       음식       Q09     유흥주점
# 346225  18455989      석정칼국수    NaN         Q       음식       Q04       분식
# 346226  18454507   서울왕도숯불갈비    NaN         Q       음식       Q01       한식
#
#        상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...       건물명                  도로명주소  \
# ...

# %%
df_filter = df[df.상권업종대분류명=='음식'].iloc[:, 0:11]
df_filter.상권업종소분류명.value_counts()
# Out:
# 한식/백반/한정식      27426
# 커피전문점/카페/다방    19494
# 호프/맥주           5811
# 라면김밥분식          5612
# 후라이드/양념치킨       4179
#                ...
# 유산균아이스크림전문         2
# 해물부페               2
# 락카페                2
# 징기스칸요리전문           1
# 재첩국전문              1
# Name: 상권업종소분류명, Length: 115, dtype: int64
